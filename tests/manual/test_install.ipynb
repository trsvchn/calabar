# %% [markdown]
# [![Open In Colab!](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/trsvchn/calabar/blob/master/tests/manual/test_install.ipynb)

# %% [markdown]
# # Testing the Installation Process

# %%
# !pip install git+https://github.com/trsvchn/calabar.git

# %%
import calabar
