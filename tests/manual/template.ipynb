# %% [markdown]
# [![Open In Colab!](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/trsvchn/coutils/blob/master/tests/manual/test_template.ipynb)

# %% [markdown]
# # Template Notebook for Manual Tests

# %%
# !pip install git+https://github.com/trsvchn/coutils.git
